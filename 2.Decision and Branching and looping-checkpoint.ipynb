# %% [markdown]
#  - ## In this article, you will learn to create decisions in a Python program using different forms of if..else statement. Also we will see loopings technique available to us in python.
#      - ### If statement
#      - ### If else statement
#      - ### IF elif else statement
#      - ### For loop
#      - ### While loop
#      - ### Break statement
#      - ### Continue statement
#      - ### Pass

# %% [markdown]
# # If statement in Python

# %% [markdown]
# ![Python_if_statement.jpg](attachment:Python_if_statement.jpg)

# %%
# If the number is positive, we print an appropriate message

num = 3
if num > 0:
    print(num, "is a positive number.")
print("This is always printed.")


num = -1
if num > 0:
    print(num, "is a positive number.")
print("This is also always printed.")

# %% [markdown]
# In the above example, num > 0 is the test expression.
#
# The body of if is executed only if this evaluates to True.
#
# When variable num is equal to 3, test expression is true and body inside if is executed.
#
# If variable num is equal to -1, test expression is false and body inside if is skipped.
#
# The print() statement falls outside of the if block (unindented). Hence, it is executed regardless of the test expression.

# %% [markdown]
# # If else statement in Python

# %% [markdown]
# ![Python_if_else_statement.jpg](attachment:Python_if_else_statement.jpg)

# %%
# Program checks if the number is positive or negative
# And displays an appropriate message

num = 3

# Try these two variations as well. 
# num = -5
# num = 0

if num >= 0:
    print("Positive or Zero")
else:
    print("Negative number")

# %% [markdown]
# In the above example, when num is equal to 3, the test expression is true and body of if is executed and body of else is skipped.
#
# If num is equal to -5, the test expression is false and body of else is executed and body of if is skipped.
#
# If num is equal to 0, the test expression is true and body of if is executed and body of else is skipped.

# %% [markdown]
# # If  elif else statement in Python

# %% [markdown]
# ![Python_if_elif_else_statement.jpg](attachment:Python_if_elif_else_statement.jpg)

# %%
# In this program, 
# we check if the number is positive or
# negative or zero and 
# display an appropriate message

num = 3.4

# Try these two variations as well:
# num = 0
# num = -4.5

if num > 0:
    print("Positive number")
elif num == 0:
    print("Zero")

else:
    print("Negative number")
# Out:
# Positive number

# %% [markdown]
# When variable num is positive, Positive number is printed.
#
# If num is equal to 0, Zero is printed.
#
# If num is negative, Negative number is printed

# %% [markdown]
# # Looping in python
# #### In python we have 2 loop commands namely : FOR and WHILE loop
# #### A loop is used to iterate over a sqquence (list, tuple, string) or any iterable objects.

# %% [markdown]
# ###   FOR Loop
# ![forLoop.jpg](attachment:forLoop.jpg)

# %%
# Program to find the sum of all numbers stored in a list

# List of numbers
numbers = [6, 5, 3, 8, 4, 2, 5, 4, 11]
# string = ["6", "5", "3", "8", "4", "2", "5", "4", "11"]

# variable to store the sum
sum = int()
print(sum)
# sum = str()

# iterate(looping) over the list
# for val in numbers:
#     print("adding {} + {}".format(sum, val))
#     sum = sum + val
#     print("result =  {}\n".format(sum))

string = "this is a test"
for i in string:
    print(i)
    

# Output: The sum is 48
print("The sum is" , sum)
# Out:
# 0
# t
# h
# i
# s
#
# i
# s
#
# a
#
# t
# e
# s
# t
# The sum is 0

# %% [markdown]
# ###   WHILE Loop
# ![whileLoopFlowchart.jpg](attachment:whileLoopFlowchart.jpg)

# %%
# Program to add natural
# numbers upto 
# sum = 1+2+3+...+n

# To take input from the user,
# n = int(input("Enter n: "))

n = 10

# initialize sum and counter
sum = 0
i = 1

while i <= n:
    sum = sum + i
    i = i+1    # update counter

while False:
    print("test")
# print the sum
print("The sum is", sum)
# Out:
# The sum is 55

# %% [markdown]
# # Break, Continue and Pass in Python

# %% [markdown]
# ### BREAK
# #### Break and Continue statements can alter the flow of a normal loop.
# #### The break statement terminates the loop containing it. Control of the program flows to the statement immediately after the body of the loop.
#
# #### If break statement is inside a nested loop (loop inside another loop), break will terminate the innermost loop.

# %% [markdown]
# ![flowchart-break-statement.jpg](attachment:flowchart-break-statement.jpg)
# ![how-break-statement-works.jpg](attachment:how-break-statement-works.jpg)
# ##### In this program, we iterate through the "string" sequence. We check if the letter is "i", upon which we break from the loop. Hence, we see in our output that all the letters up till "i" gets printed. After that, the loop terminates.

# %%
# Use of break statement inside loop

for val in "string":
    if val == "i":
        break
    print(val)

print("The end")
# Out:
# s
# t
# r
# The end

# %%
# Use of break for nested loop
print("The start before outer loop.\n")
for outerval in "1234":
    print("The start before inner loop."+outerval)
    for val in "string":
        if val == "i":
            break
        print(val)

    print("The end after inner loop."+outerval)
print("\nThe end after the outer loop.")
# Out:
# The start before outer loop.
#
# The start before inner loop.1
# s
# t
# r
# The end after inner loop.1
# The start before inner loop.2
# s
# t
# r
# The end after inner loop.2
# The start before inner loop.3
# s
# t
# r
# The end after inner loop.3
# The start before inner loop.4
# s
# t
# r
# The end after inner loop.4
#
# The end after the outer loop.

# %% [markdown]
# ### CONTINUE
# #### The continue statement is used to skip the rest of the code inside a loop for the current iteration only. Loop does not terminate but continues on with the next iteration.

# %% [markdown]
# ![continue-statement-flowchart.jpg](attachment:continue-statement-flowchart.jpg)
# ![how-continue-statment-works.jpg](attachment:how-continue-statment-works.jpg)
#
# #### This program is same as the above example except the break statement has been replaced with continue.
#
# #### We continue with the loop, if the string is "i", not executing the rest of the block. Hence, we see in our output that all the letters except "i" gets printed.

# %%
# Program to show the use of continue statement inside loops

for val in "string":
    if val == "i":
        continue
    print(val)

print("The end")
# Out:
# s
# t
# r
# n
# g
# The end

# %%
# Use of continue for nested loop 
print("The start for outer loop.\n")
for outerval in "1234":
    print("The start for inner loop. {}".format(outerval))
    for val in "string":
        if val == "i":
            continue
        print(val)
    if outerval == "3":
        continue
    print("The end for inner loop.{}\n".format(outerval))
    
print("\n The end for outer loop.")
# Out:
# The start for outer loop.
#
# The start for inner loop. 1
# s
# t
# r
# n
# g
# The end for inner loop.1
#
# The start for inner loop. 2
# s
# t
# r
# n
# g
# The end for inner loop.2
#
# The start for inner loop. 3
# s
# t
# r
# n
# g
# The start for inner loop. 4
# s
# t
# r
# n
# g
# The end for inner loop.4
#
#
#  The end for outer loop.

# %% [markdown]
# ### What is pass statement in Python?
#   #### In Python programming, pass is a null statement. The difference between a comment and pass statement in Python is that, while the interpreter ignores a comment entirely, pass is not ignored.

# %%
# pass is just a placeholder for
# functionality to be added later.
sequence = {'a','b','c','e','f','i','j','k','o','p','q','u','v','z'}
vowels = {'a', 'e', 'i', 'o', 'u'}
for val in sequence:
    if val in vowels:
        print("Found vowel {} in sequence.".format(val))
    else:
#         print("{} Not a vowel".format(val))
        pass
# Out:
# j Not a vowel
# Found vowel o in sequence.
# c Not a vowel
# Found vowel u in sequence.
# b Not a vowel
# Found vowel i in sequence.
# f Not a vowel
# k Not a vowel
# z Not a vowel
# q Not a vowel
# p Not a vowel
# Found vowel e in sequence.
# Found vowel a in sequence.
# v Not a vowel
